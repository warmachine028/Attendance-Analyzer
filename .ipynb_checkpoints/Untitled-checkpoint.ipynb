# %%
import camelot
tables = camelot.read_pdf('student_attendance.pdf')#, pages='1')
# for table in tables:
#     table.df
tables[0].df
# Out:
#                                                     0                   1  \
# 0   University of Engineering & Management , Kolka...
# 1                                                      Section Class Roll
# 2                                                   A                   1
# 3                                                   A                   2
# 4                                                   A                   3
# 5                                                   A                   4
# 6                                                   A                   5
# 7                                                   A                   6
# 8                                                   A                   7
# 9                                                   A                   8
# 10                                                  A                   9
# 11                                                  A                  10
# ...
